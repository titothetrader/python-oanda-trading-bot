# %%
import pandas as pd
import plotly.graph_objects as go

# %%
ma_test_res = pd.read_pickle("ma_test_res.pkl")
all_trades = pd.read_pickle("all_trades.pkl")

# %%
all_trades.shape
# Out:
# (251478, 11)

# %%
ma_test_res.shape
# Out:
# (630, 8)

# %%
ma_test_res.head()
# Out:
#       pair  num_trades  total_gain  mashort  malong    CROSS
# 0  GBP_USD        2020     -1164.4        4       8   MA_4_8
# 1  GBP_USD        1204      -549.9        4      16  MA_4_16
# 2  GBP_USD        1030       655.5        8      16  MA_8_16
# 3  GBP_USD         787       -56.5        4      32  MA_4_32
# 4  GBP_USD         632      -305.4        8      32  MA_8_32

# %%
ma_test_res.columns
# Out:
# Index(['pair', 'num_trades', 'total_gain', 'mean_gain', 'min_gain', 'max_gain',
#        'mashort', 'malong'],
#       dtype='object')

# %%
ma_test_res = ma_test_res[['pair', 'num_trades', 'total_gain', 'mashort', 'malong']]

# %%
ma_test_res["CROSS"] = "MA_" + ma_test_res.mashort.map(str) + "_" + ma_test_res.malong.map(str)

# %%
df_all_gains = ma_test_res.groupby(by=["CROSS", "mashort", "malong"], as_index=False).sum()

# %%
df_all_gains.head()
# Out:
#        CROSS  mashort  malong  num_trades  total_gain
# 0  MA_16_128       16     128        3803     -2444.7
# 1  MA_16_256       16     256        2615     -7411.5
# 2   MA_16_32       16      32       11175     -6630.2
# 3   MA_16_64       16      64        6233     -2306.4
# 4   MA_16_96       16      96        4569      -362.6

# %%
df_all_gains.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
df_all_gains.head()
# Out:
#        CROSS  mashort  malong  num_trades  total_gain
# 12  MA_32_64       32      64        5426      2718.4
# 8   MA_24_64       24      64        5659      1622.1
# 13  MA_32_96       32      96        3657      1413.0
# 9   MA_24_96       24      96        3972       -36.1
# 4   MA_16_96       16      96        4569      -362.6

# %%
ma_32_64 = ma_test_res[ma_test_res.CROSS=='MA_32_64'].copy()

# %%
ma_32_64.head()
# Out:
#         pair  num_trades  total_gain  mashort  malong     CROSS
# 11   GBP_USD         249       500.6       32      64  MA_32_64
# 41   GBP_CAD         262       303.7       32      64  MA_32_64
# 71   GBP_JPY         253       825.1       32      64  MA_32_64
# 101  GBP_NZD         288      -936.0       32      64  MA_32_64
# 131  GBP_CHF         264      -892.7       32      64  MA_32_64

# %%
ma_32_64.sort_values(by="total_gain", ascending=False, inplace=True)

# %%
ma_32_64.head(10)
# Out:
#         pair  num_trades  total_gain  mashort  malong     CROSS
# 431  CAD_JPY         245      1113.3       32      64  MA_32_64
# 221  EUR_CAD         263      1050.4       32      64  MA_32_64
# 551  NZD_JPY         234       959.1       32      64  MA_32_64
# 71   GBP_JPY         253       825.1       32      64  MA_32_64
# 251  EUR_JPY         241       574.2       32      64  MA_32_64
# 11   GBP_USD         249       500.6       32      64  MA_32_64
# 521  NZD_CAD         242       387.0       32      64  MA_32_64
# 491  NZD_USD         266       381.3       32      64  MA_32_64
# 41   GBP_CAD         262       303.7       32      64  MA_32_64
# 371  USD_JPY         263       198.3       32      64  MA_32_64

# %%
ma_32_64.pair.unique()
# Out:
# array(['CAD_JPY', 'EUR_CAD', 'NZD_JPY', 'GBP_JPY', 'EUR_JPY', 'GBP_USD',
#        'NZD_CAD', 'NZD_USD', 'GBP_CAD', 'USD_JPY', 'CHF_JPY', 'EUR_GBP',
#        'USD_CHF', 'NZD_CHF', 'USD_CAD', 'CAD_CHF', 'EUR_CHF', 'EUR_NZD',
#        'EUR_USD', 'GBP_CHF', 'GBP_NZD'], dtype=object)

# %%
total_p = len(ma_32_64.pair.unique())

# %% [markdown]
# Get all trades that were positive

# %%
ma_32_64[ma_32_64.total_gain>0].shape[0]
# Out:
# 13

# %%
total_p
# Out:
# 21

# %%
13 / total_p
# Out:
# 0.6190476190476191

# %% [markdown]
# Go through ALL ma cross combinations

# %%
df_all_gains.CROSS.unique()
# Out:
# array(['MA_32_64', 'MA_24_64', 'MA_32_96', 'MA_24_96', 'MA_16_96',
#        'MA_24_128', 'MA_16_64', 'MA_16_128', 'MA_8_128', 'MA_8_96',
#        'MA_8_64', 'MA_32_128', 'MA_4_128', 'MA_64_128', 'MA_24_32',
#        'MA_4_96', 'MA_64_96', 'MA_16_32', 'MA_16_256', 'MA_8_256',
#        'MA_4_256', 'MA_24_256', 'MA_4_64', 'MA_8_16', 'MA_32_256',
#        'MA_64_256', 'MA_8_32', 'MA_4_32', 'MA_4_16', 'MA_4_8'],
#       dtype=object)

# %%
for cross in df_all_gains.CROSS.unique():
    print(cross)
# Out:
# MA_32_64
# MA_24_64
# MA_32_96
# MA_24_96
# MA_16_96
# MA_24_128
# MA_16_64
# MA_16_128
# MA_8_128
# MA_8_96
# MA_8_64
# MA_32_128
# MA_4_128
# MA_64_128
# MA_24_32
# MA_4_96
# MA_64_96
# MA_16_32
# MA_16_256
# MA_8_256
# MA_4_256
# MA_24_256
# MA_4_64
# MA_8_16
# MA_32_256
# MA_64_256
# MA_8_32
# MA_4_32
# MA_4_16
# MA_4_8

# %%
for cross in df_all_gains.CROSS.unique():
    df_temp = ma_test_res[ma_test_res.CROSS==cross]
    # print(cross)
    # print(df_temp.head())
    total_p = df_temp.shape[0]
    n_good = df_temp[df_temp.total_gain>0].shape[0]
    print(f"{cross:12} {n_good:4} {(n_good/total_p)*100:4.0f}%")
# Out:
# MA_32_64       13   62%
# MA_24_64       13   62%
# MA_32_96       12   57%
# MA_24_96       10   48%
# MA_16_96       10   48%
# MA_24_128       9   43%
# MA_16_64       13   62%
# MA_16_128       8   38%
# MA_8_128       11   52%
# MA_8_96         9   43%
# MA_8_64        11   52%
# MA_32_128       7   33%
# MA_4_128        5   24%
# MA_64_128       9   43%
# MA_24_32        9   43%
# MA_4_96         9   43%
# MA_64_96        6   29%
# MA_16_32        8   38%
# MA_16_256       5   24%
# MA_8_256        5   24%
# MA_4_256        7   33%
# MA_24_256       4   19%
# MA_4_64        10   48%
# MA_8_16         9   43%
# MA_32_256       4   19%
# MA_64_256       6   29%
# MA_8_32         6   29%
# MA_4_32         6   29%
# MA_4_16         5   24%
# MA_4_8          3   14%

# %%
crosses = df_all_gains.CROSS.unique()[:3]
crosses
# Out:
# array(['MA_32_64', 'MA_24_64', 'MA_32_96'], dtype=object)

# %%
ma_test_res.head(2)
# Out:
#       pair  num_trades  total_gain  mashort  malong    CROSS
# 0  GBP_USD        2020     -1164.4        4       8   MA_4_8
# 1  GBP_USD        1204      -549.9        4      16  MA_4_16

# %%
df_good = ma_test_res[(ma_test_res.CROSS.isin(crosses))&(ma_test_res.total_gain>0)].copy()

# %%
df_good.head(2)
# Out:
#        pair  num_trades  total_gain  mashort  malong     CROSS
# 10  GBP_USD         261       939.1       24      64  MA_24_64
# 11  GBP_USD         249       500.6       32      64  MA_32_64

# %%
df_good.pair.value_counts()
# Out:
# GBP_USD    3
# GBP_JPY    3
# EUR_CAD    3
# USD_JPY    3
# CAD_JPY    3
# NZD_USD    3
# NZD_CAD    3
# NZD_JPY    3
# CHF_JPY    3
# GBP_CAD    2
# EUR_GBP    2
# EUR_JPY    2
# USD_CHF    2
# GBP_NZD    1
# USD_CAD    1
# NZD_CHF    1
# Name: pair, dtype: int64

# %%
df_good.pair.value_counts()[:9]
# Out:
# GBP_USD    3
# GBP_JPY    3
# EUR_CAD    3
# USD_JPY    3
# CAD_JPY    3
# NZD_USD    3
# NZD_CAD    3
# NZD_JPY    3
# CHF_JPY    3
# Name: pair, dtype: int64

# %%
df_good.pair.value_counts()[:9].index
# Out:
# Index(['GBP_USD', 'GBP_JPY', 'EUR_CAD', 'USD_JPY', 'CAD_JPY', 'NZD_USD',
#        'NZD_CAD', 'NZD_JPY', 'CHF_JPY'],
#       dtype='object')

# %%
list(df_good.pair.value_counts()[:9].index)
# Out:
# ['GBP_USD',
#  'GBP_JPY',
#  'EUR_CAD',
#  'USD_JPY',
#  'CAD_JPY',
#  'NZD_USD',
#  'NZD_CAD',
#  'NZD_JPY',
#  'CHF_JPY']

# %%
our_pairs = list(df_good.pair.value_counts()[:9].index)
our_pairs
# Out:
# ['GBP_USD',
#  'GBP_JPY',
#  'EUR_CAD',
#  'USD_JPY',
#  'CAD_JPY',
#  'NZD_USD',
#  'NZD_CAD',
#  'NZD_JPY',
#  'CHF_JPY']

# %% [markdown]
# Now get all trades by each of these pais that had best results from our crosses

# %%
all_trades.head(2)
# Out:
#                         time    mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA  \
# 15 2021-04-13 13:00:00+00:00  1.37514  0.000442  -0.000012         1  -21.4
# 20 2021-04-13 14:00:00+00:00  1.37300 -0.000268   0.000268        -1    7.4
#
#     GAIN     PAIR  MASHORT  MALONG  DURATION
# 15 -21.4  GBP_USD        4       8       1.0
# 20  -7.4  GBP_USD        4       8       2.0

# %%
all_trades["CROSS"] = "MA_" + all_trades.MASHORT.map(str) + "_" + all_trades.MALONG.map(str)

# %%
trades_cad_jpy = all_trades[(all_trades.CROSS=="MA_32_64") & (all_trades.PAIR=="CAD_JPY")].copy()
trades_cad_jpy.head()
# Out:
#                          time   mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA  \
# 97  2021-04-14 17:00:00+00:00  87.031  0.002313  -0.003391         1    2.1
# 151 2021-04-15 11:00:00+00:00  87.052 -0.000766   0.000672        -1    0.0
# 152 2021-04-15 11:00:00+00:00  87.052  0.000328  -0.000766         1  -12.6
# 153 2021-04-15 12:00:00+00:00  86.926 -0.000547   0.000328        -1    0.0
# 154 2021-04-15 12:00:00+00:00  86.926  0.000141  -0.000547         1    0.0
#
#      GAIN     PAIR  MASHORT  MALONG  DURATION     CROSS
# 97    2.1  CAD_JPY       32      64      18.0  MA_32_64
# 151  -0.0  CAD_JPY       32      64       0.0  MA_32_64
# 152 -12.6  CAD_JPY       32      64       1.0  MA_32_64
# 153  -0.0  CAD_JPY       32      64       0.0  MA_32_64
# 154   0.0  CAD_JPY       32      64       0.0  MA_32_64

# %%
trades_cad_jpy['CUM_GAIN'] = trades_cad_jpy.GAIN.cumsum()
trades_cad_jpy.head()
# Out:
#                          time   mid_c      DIFF  DIFF_PREV  IS_TRADE  DELTA  \
# 97  2021-04-14 17:00:00+00:00  87.031  0.002313  -0.003391         1    2.1
# 151 2021-04-15 11:00:00+00:00  87.052 -0.000766   0.000672        -1    0.0
# 152 2021-04-15 11:00:00+00:00  87.052  0.000328  -0.000766         1  -12.6
# 153 2021-04-15 12:00:00+00:00  86.926 -0.000547   0.000328        -1    0.0
# 154 2021-04-15 12:00:00+00:00  86.926  0.000141  -0.000547         1    0.0
#
#      GAIN     PAIR  MASHORT  MALONG  DURATION     CROSS  CUM_GAIN
# 97    2.1  CAD_JPY       32      64      18.0  MA_32_64       2.1
# 151  -0.0  CAD_JPY       32      64       0.0  MA_32_64       2.1
# 152 -12.6  CAD_JPY       32      64       1.0  MA_32_64     -10.5
# 153  -0.0  CAD_JPY       32      64       0.0  MA_32_64     -10.5
# 154   0.0  CAD_JPY       32      64       0.0  MA_32_64     -10.5

# %% [markdown]
# Getting ready for PLOTTING

# %%
def plot_line(df_plot, name):
    fig = go.Figure()
    fig.add_trace(go.Scatter(
        x = df_plot.time, 
        y=df_plot.CUM_GAIN,
        line=dict(width=2,color="#3d825f"),
        line_shape='spline',
        name="CAD_CUM_GAIN",
        mode='lines'
    ))
    fig.update_layout(width=1000,height=400,
        margin=dict(l=15, r=15, b=15),
        font=dict(size=10,color="#e1e1e1"),
        paper_bgcolor="#1e1e1e", 
        plot_bgcolor="#1e1e1e",
        title=name)
    fig.update_xaxes(
        linewidth=1,
        linecolor='#3a4a54',
        showgrid=False,
        zeroline=False)
    fig.update_yaxes(
        linewidth=1,
        linecolor='#3a4a54',
        showgrid=False,
        zeroline=False)
    fig.show()

# %%
plot_line(trades_cad_jpy, "CAD_JPY")

# %% [markdown]
# Now lets look at all the players

# %%
c = 'MA_32_64'
for p in our_pairs:
    temp_df = all_trades[(all_trades.CROSS==c) & (all_trades.PAIR==p)].copy()
    temp_df['CUM_GAIN'] = temp_df.GAIN.cumsum()
    plot_line(temp_df, p + "_" + c)

# %%
for c in crosses:
    temp_df = all_trades[(all_trades.CROSS==c)].copy()
    temp_df = temp_df.groupby(by='time', as_index=False).sum()
    temp_df['CUM_GAIN'] = temp_df.GAIN.cumsum()
    plot_line(temp_df, c)

# %%
temp_df.head(10)
# Out:
#                        time      mid_c      DIFF     DIFF_PREV  IS_TRADE  \
# 0 2021-04-14 19:00:00+00:00   86.99600  0.000406 -4.270833e-04         1
# 1 2021-04-14 23:00:00+00:00    1.72466 -0.000016  1.481250e-04        -1
# 2 2021-04-15 00:00:00+00:00    1.49931 -0.000088  3.125000e-07        -1
# 3 2021-04-15 05:00:00+00:00  150.02200 -0.000010  3.322917e-03        -1
# 4 2021-04-15 09:00:00+00:00  130.29000 -0.000781  6.750000e-03        -1
# 5 2021-04-15 10:00:00+00:00    1.37649 -0.000049  3.270833e-05        -1
# 6 2021-04-15 13:00:00+00:00    1.37856  0.000007 -2.156250e-05         1
# 7 2021-04-15 14:00:00+00:00    0.86783 -0.000047  8.750000e-06        -1
# 8 2021-04-15 15:00:00+00:00    1.19627 -0.000011  1.833333e-05        -1
# 9 2021-04-15 16:00:00+00:00   88.69952 -0.000130  9.662500e-03        -3
#
#    DELTA  GAIN  MASHORT  MALONG  DURATION
# 0  -32.3 -32.3       32      96      21.0
# 1   42.4 -42.4       32      96      19.0
# 2   18.5 -18.5       32      96      20.0
# 3   14.0 -14.0       32      96      32.0
# 4    6.0  -6.0       32      96      24.0
# 5   20.7 -20.7       32      96       3.0
# 6  -26.6 -26.6       32      96      13.0
# 7   38.0 -38.0       32      96      16.0
# 8   20.1 -20.1       32      96      20.0
# 9  -75.5  75.5       96     288     239.0
